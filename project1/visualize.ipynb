# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path = "/Users/abhishekvcp/Downloads"

my_cols = ['Month',"Name","Amount"]

df = pd.read_excel(f"{path}/EXP-TrACKER-NEW.xlsx", usecols=my_cols)
df.info()
#df.head()
df.isnull().any(axis=1)
df.head()

# chartng options
"""ArithmeticError
sns.lineplot(x=df["Month"],y=df["Amount"])
plt.show()
df["Amount"].plot(kind='line',color='red')
plt.show()
"""
sns.histplot(df["Amount"],bins=range(1,2000,100))
sns.set_style('darkgrid')
plt.xlim(1,5000)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 556 entries, 0 to 555
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   556 non-null    datetime64[ns]
#  1   Name    556 non-null    object
#  2   Amount  541 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 13.2+ KB
